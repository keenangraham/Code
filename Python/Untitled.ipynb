# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
GB = pd.read_excel('GIARBOX.xls', header=None)

# %%
GB = GB.rename(columns={0:"Order#"})

# %%
EIAG = pd.read_excel('EIAG Final.xlsx', header=None)

# %%
EIAG = EIAG.rename(columns={0:'Order#'})

# %%
GIAR = pd.read_excel('RGIAR Final.xls')

# %%
L = T.merge(EIAG, how='outer', on='Order#')

# %%
T.describe()
# Out:
#           Order# Type   Test       Results            Ord. Date  \
# count        182   61    155           155                  155
# unique       182    1      1            12                  128
# top     H9110726  Box  RGIAR  RARE CYST(S)  2014-03-27 00:00:00
# freq           1   61    155            33                    3
# first        NaN  NaN    NaN           NaN  2014-01-17 00:00:00
# last         NaN  NaN    NaN           NaN  2015-08-31 00:00:00
#
#                 Ward Name
# count                 155
# unique                 91
# top     Referring Atlanta
# freq                   23
# first                 NaN
# last                  NaN

# %%
L
# Out:
#        Order# Type   Test        Results  Ord. Date  \
# 0    I3070320  Box  RGIAR    MOD CYST(S) 2015-03-07
# 1    I3060086  Box    NaN            NaN        NaT
# 2    I3041171  Box    NaN            NaN        NaT
# 3    I2260295  Box    NaN            NaN        NaT
# 4    I2180134  Box  RGIAR    FEW CYST(S) 2015-02-18
# 5    I2201021  Box  RGIAR        MOD T/C 2015-02-20
# 6    I2120897  Box  RGIAR    MOD CYST(S) 2015-02-12
# 7    I1211050  Box    NaN            NaN        NaT
# 8    I1150080  Box  RGIAR   RARE CYST(S) 2015-01-15
# 9    I1170466  Box  RGIAR        FEW T/C 2015-01-17
# 10   I3110068  Box  RGIAR    FEW CYST(S) 2015-03-11
# 11   I3121279  Box  RGIAR   RARE CYST(S) 2015-03-12
# 12   I3111070  Box  RGIAR  MANY TROPH(S) 2015-03-11
# 13   I3270108  Box  RGIAR    FEW CYST(S) 2015-03-27
# 14   I3250371  Box  RGIAR   RARE CYST(S) 2015-03-25
# 15   I4021018  Box    NaN            NaN        NaT
# 16   I1100443  Box  RGIAR        MOD T/C 2015-01-10
# ...

# %%
L[(L.Type == 'Box') & (L[1] != 'PCPAR') & (L.Test != 'RGIAR')]['Order#']
# Out:
# 1     I3060086
# 2     I3041171
# 3     I2260295
# 17    I4080063
# 20    I4270232
# 40    I9181040
# 41    I9170159
# 42    I9110033
# 43    I9020354
# 44    I9020275
# 50    I9190386
# 51    J0160171
# 52    J0151126
# 53    J0130630
# 54    J0090468
# 55    J0070143
# 56    J0061175
# 57    J0030221
# 58    I9240899
# 59    I9221031
# 60    J0210392
# Name: Order#, dtype: object
